# %%
import torch
import matplotlib.pyplot as plt

import featurevis
from featurevis import models
from featurevis import ops
from featurevis import utils


device = 'cuda' if torch.cuda.is_available() else 'cpu'
if device == 'cpu': 
    print('Running models on CPU!')

# %% [markdown]
# First, let's get a pre-trained model for neurons

# %%
from staticnet_analyses import multi_mei
from staticnet_experiments import models as static_models

key = {'data_hash': '7572eed73113c993e7d1b92f83e270b4', 'group_id': 29, 
       'net_hash': '80d0d4bc112470b2ba04cd5eba048e39', 'neuron_id': 119, 
       'readout_key': 'group029-21067-9-17-0'}

# Get our f (average of four models)
train_stats = multi_mei.prepare_data(key, key['readout_key'])
_, (_, _, height, width), _, mean_behavior, mean_eyepos, _ = train_stats
model_key = {'group_id': key['group_id'], 'net_hash': key['net_hash']}
my_models = [(static_models.Model & mk).load_network() for mk in (static_models.Model & model_key).proj()]
model = models.Ensemble(my_models, key['readout_key'], eye_pos=mean_eyepos, neuron_idx=key['neuron_id'], device=device)
# Out:
# Connecting ecobost@at-database.ad.bcm.edu:3306
# 30-07-2019:06:16:46 INFO     configs.py           224:	 Ignoring input arguments: ""when creating datasets
# 30-07-2019:06:16:46 INFO     configs.py           203:	 Loading None dataset with tier=None
# 30-07-2019:06:16:46 INFO     data_schemas.py      977:	 Fetching data for {'data_hash': '7572eed73113c993e7d1b92f83e270b4', 'group_id': 29, 'net_hash': '80d0d4bc112470b2ba04cd5eba048e39', 'neuron_id': 119, 'readout_key': 'group029-21067-9-17-0', 'data_description': "V1 L2/3 on stimulus.Frame. normalize=True on all (except '')", 'stats_source': 'all', 'normalize': 1, 'normalize_per_image': 0, 'layer': 'L2/3', 'brain_area': 'V1'}
# 30-07-2019:06:16:46 INFO     data_schemas.py      987:	 Data will be (images,behavior,pupil_center,responses)
# 30-07-2019:06:16:46 INFO     data_schemas.py      990:	 Loading dataset group029-21067-9-17-0 --> /external/cache/static21067-9-17-preproc0.h5
# 30-07-2019:06:16:46 INFO     configs.py           208:	 Adding stats_source "all" to dataset
# 30-07-2019:06:16:46 INFO     configs.py           211:	 Using statistics source all
# 30-07-2019:06:16:46 INFO     configs.py            85:	 Excluding "" from normalization
# 30-07-2019:06:16:46 INFO     configs.py           177:	 Using stimulus.Frame as stimulus type for all datasets
# 30-07-2019:06:16:46 INFO     configs.py           180:	 Stimulus sources: "stimulus.Frame"
# 30-07-2019:06:16:46 INFO     configs.py           114:	 Using all trial from stimulus.Frame
# 30-07-2019:06:16:46 INFO     configs.py           188:	 Selecting trials from stimulus.Frame and tier=None for dataset group029-21067-9-17-0
# /src/static-networks/staticnet_analyses/multi_mei.py:1825: UserWarning: Use of this table is deprecated. It is kept only for record keeping purpose
#   warnings.warn('Use of this table is deprecated. It is kept only for record keeping purpose')
# /usr/local/lib/python3.6/dist-packages/h5py/_hl/dataset.py:313: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   "Use dataset[()] instead.", H5pyDeprecationWarning)
# 30-07-2019:06:16:46 INFO     configs.py           190:	 Found 5998 active trials
# 30-07-2019:06:16:46 INFO     configs.py           150:	 Loader sampler is SubsetSequentialSampler
# 30-07-2019:06:16:46 INFO     configs.py           152:	 Number of samples in the loader will be 5998
# 30-07-2019:06:16:46 INFO     configs.py           154:	 Number of batches in the loader will be 5998
# 30-07-2019:06:16:46 INFO     configs.py           233:	 Subsampling to layer L2/3 and area(s) "V1"
# 30-07-2019:06:16:46 INFO     configs.py           399:	 Setting cuda=False
# 30-07-2019:06:16:50 INFO     configs.py           224:	 Ignoring input arguments: "net_hash", "core_hash", "ro_hash", "shift_hash", "mod_hash", "train_hash", "data_hash", "group_id", "seed", "train_type", "schedule", "max_epoch"when creating datasets
# 30-07-2019:06:16:50 INFO     configs.py           203:	 Loading None dataset with tier=train
# 30-07-2019:06:16:50 INFO     data_schemas.py      977:	 Fetching data for {'net_hash': '80d0d4bc112470b2ba04cd5eba048e39', 'core_hash': '28bc2fa358337c5012278f899b5b6947', 'ro_hash': 'e4cd67efe5a543b044cf8a74e440775e', 'shift_hash': '05c69a4aeaeea5e48fa8fc5e70181d67', 'mod_hash': 'a757e992ae449e3057ff1d512a51bd1e', 'train_hash': '2c25349fa0a81afbe907882e7b50a4da', 'data_hash': '7572eed73113c993e7d1b92f83e270b4', 'group_id': 29, 'seed': 1009, 'data_description': "V1 L2/3 on stimulus.Frame. normalize=True on all (except '')", 'stats_source': 'all', 'normalize': 1, 'normalize_per_image': 0, 'layer': 'L2/3', 'brain_area': 'V1'}
# 30-07-2019:06:16:50 INFO     data_schemas.py      987:	 Data will be (images,behavior,pupil_center,responses)
# 30-07-2019:06:16:50 INFO     data_schemas.py      990:	 Loading dataset group029-21067-9-17-0 --> /external/cache/static21067-9-17-preproc0.h5
# 30-07-2019:06:16:50 INFO     configs.py           208:	 Adding stats_source "all" to dataset
# 30-07-2019:06:16:50 INFO     configs.py           211:	 Using statistics source all
# 30-07-2019:06:16:50 INFO     configs.py            85:	 Excluding "" from normalization
# 30-07-2019:06:16:50 INFO     configs.py           177:	 Using stimulus.Frame as stimulus type for all datasets
# 30-07-2019:06:16:50 INFO     configs.py           180:	 Stimulus sources: "stimulus.Frame"
# 30-07-2019:06:16:50 INFO     configs.py           114:	 Using all trial from stimulus.Frame
# 30-07-2019:06:16:50 INFO     configs.py           188:	 Selecting trials from stimulus.Frame and tier=train for dataset group029-21067-9-17-0
# 30-07-2019:06:16:50 INFO     configs.py           190:	 Found 4475 active trials
# 30-07-2019:06:16:50 INFO     configs.py           150:	 Loader sampler is SubsetRandomSampler
# 30-07-2019:06:16:50 INFO     configs.py           152:	 Number of samples in the loader will be 4475
# 30-07-2019:06:16:50 INFO     configs.py           154:	 Number of batches in the loader will be 75
# 30-07-2019:06:16:50 INFO     configs.py           233:	 Subsampling to layer L2/3 and area(s) "V1"
# 30-07-2019:06:16:50 INFO     configs.py           399:	 Setting cuda=False
# 30-07-2019:06:16:50 INFO     cores.py              76:	 Ignoring input {'core_hash': '28bc2fa358337c5012278f899b5b6947'} when creating GaussianLaplaceCore
# 30-07-2019:06:16:50 INFO     readouts.py          140:	 Ignoring input {'ro_hash': 'e4cd67efe5a543b044cf8a74e440775e'} when creating SpatialTransformerPyramid2dReadout
# 30-07-2019:06:16:50 INFO     shifters.py           56:	 Ignoring input {'shift_hash': '05c69a4aeaeea5e48fa8fc5e70181d67'} when creating MLPShifter
# 30-07-2019:06:16:50 INFO     shifters.py           28:	 Ignoring input {} when creating MLP
# 30-07-2019:06:16:50 INFO     modulators.py         47:	 Ignoring input {'mod_hash': 'a757e992ae449e3057ff1d512a51bd1e'} when creating MLPModulator
# 30-07-2019:06:16:50 INFO     modulators.py         18:	 Ignoring input {} when creating MLP
# /usr/local/lib/python3.6/dist-packages/h5py/_hl/dataset.py:313: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   "Use dataset[()] instead.", H5pyDeprecationWarning)
# 30-07-2019:06:16:50 WARNING  models.py             82:	 Could not find paramater 'core.features.layer2.norm.num_batches_tracked' setting to initialization value
# 30-07-2019:06:16:50 WARNING  models.py             82:	 Could not find paramater 'core.features.layer1.norm.num_batches_tracked' setting to initialization value
# 30-07-2019:06:16:50 WARNING  models.py             82:	 Could not find paramater 'core.features.layer0.norm.num_batches_tracked' setting to initialization value
# 30-07-2019:06:16:50 INFO     configs.py           224:	 Ignoring input arguments: "net_hash", "core_hash", "ro_hash", "shift_hash", "mod_hash", "train_hash", "data_hash", "group_id", "seed", "train_type", "schedule", "max_epoch"when creating datasets
# 30-07-2019:06:16:50 INFO     configs.py           203:	 Loading None dataset with tier=train
# 30-07-2019:06:16:50 INFO     data_schemas.py      977:	 Fetching data for {'net_hash': '80d0d4bc112470b2ba04cd5eba048e39', 'core_hash': '28bc2fa358337c5012278f899b5b6947', 'ro_hash': 'e4cd67efe5a543b044cf8a74e440775e', 'shift_hash': '05c69a4aeaeea5e48fa8fc5e70181d67', 'mod_hash': 'a757e992ae449e3057ff1d512a51bd1e', 'train_hash': '2c25349fa0a81afbe907882e7b50a4da', 'data_hash': '7572eed73113c993e7d1b92f83e270b4', 'group_id': 29, 'seed': 1215, 'data_description': "V1 L2/3 on stimulus.Frame. normalize=True on all (except '')", 'stats_source': 'all', 'normalize': 1, 'normalize_per_image': 0, 'layer': 'L2/3', 'brain_area': 'V1'}
# 30-07-2019:06:16:50 INFO     data_schemas.py      987:	 Data will be (images,behavior,pupil_center,responses)
# 30-07-2019:06:16:50 INFO     data_schemas.py      990:	 Loading dataset group029-21067-9-17-0 --> /external/cache/static21067-9-17-preproc0.h5
# 30-07-2019:06:16:50 INFO     configs.py           208:	 Adding stats_source "all" to dataset
# 30-07-2019:06:16:50 INFO     configs.py           211:	 Using statistics source all
# 30-07-2019:06:16:50 INFO     configs.py            85:	 Excluding "" from normalization
# 30-07-2019:06:16:50 INFO     configs.py           177:	 Using stimulus.Frame as stimulus type for all datasets
# 30-07-2019:06:16:50 INFO     configs.py           180:	 Stimulus sources: "stimulus.Frame"
# 30-07-2019:06:16:50 INFO     configs.py           114:	 Using all trial from stimulus.Frame
# 30-07-2019:06:16:50 INFO     configs.py           188:	 Selecting trials from stimulus.Frame and tier=train for dataset group029-21067-9-17-0
# 30-07-2019:06:16:50 INFO     configs.py           190:	 Found 4475 active trials
# 30-07-2019:06:16:50 INFO     configs.py           150:	 Loader sampler is SubsetRandomSampler
# 30-07-2019:06:16:50 INFO     configs.py           152:	 Number of samples in the loader will be 4475
# 30-07-2019:06:16:50 INFO     configs.py           154:	 Number of batches in the loader will be 75
# 30-07-2019:06:16:50 INFO     configs.py           233:	 Subsampling to layer L2/3 and area(s) "V1"
# 30-07-2019:06:16:50 INFO     configs.py           399:	 Setting cuda=False
# 30-07-2019:06:16:50 INFO     cores.py              76:	 Ignoring input {'core_hash': '28bc2fa358337c5012278f899b5b6947'} when creating GaussianLaplaceCore
# 30-07-2019:06:16:50 INFO     readouts.py          140:	 Ignoring input {'ro_hash': 'e4cd67efe5a543b044cf8a74e440775e'} when creating SpatialTransformerPyramid2dReadout
# 30-07-2019:06:16:50 INFO     shifters.py           56:	 Ignoring input {'shift_hash': '05c69a4aeaeea5e48fa8fc5e70181d67'} when creating MLPShifter
# 30-07-2019:06:16:50 INFO     shifters.py           28:	 Ignoring input {} when creating MLP
# 30-07-2019:06:16:50 INFO     modulators.py         47:	 Ignoring input {'mod_hash': 'a757e992ae449e3057ff1d512a51bd1e'} when creating MLPModulator
# 30-07-2019:06:16:50 INFO     modulators.py         18:	 Ignoring input {} when creating MLP
# /usr/local/lib/python3.6/dist-packages/h5py/_hl/dataset.py:313: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   "Use dataset[()] instead.", H5pyDeprecationWarning)
# 30-07-2019:06:16:51 WARNING  models.py             82:	 Could not find paramater 'core.features.layer2.norm.num_batches_tracked' setting to initialization value
# 30-07-2019:06:16:51 WARNING  models.py             82:	 Could not find paramater 'core.features.layer1.norm.num_batches_tracked' setting to initialization value
# 30-07-2019:06:16:51 WARNING  models.py             82:	 Could not find paramater 'core.features.layer0.norm.num_batches_tracked' setting to initialization value
# 30-07-2019:06:16:51 INFO     configs.py           224:	 Ignoring input arguments: "net_hash", "core_hash", "ro_hash", "shift_hash", "mod_hash", "train_hash", "data_hash", "group_id", "seed", "train_type", "schedule", "max_epoch"when creating datasets
# 30-07-2019:06:16:51 INFO     configs.py           203:	 Loading None dataset with tier=train
# 30-07-2019:06:16:51 INFO     data_schemas.py      977:	 Fetching data for {'net_hash': '80d0d4bc112470b2ba04cd5eba048e39', 'core_hash': '28bc2fa358337c5012278f899b5b6947', 'ro_hash': 'e4cd67efe5a543b044cf8a74e440775e', 'shift_hash': '05c69a4aeaeea5e48fa8fc5e70181d67', 'mod_hash': 'a757e992ae449e3057ff1d512a51bd1e', 'train_hash': '2c25349fa0a81afbe907882e7b50a4da', 'data_hash': '7572eed73113c993e7d1b92f83e270b4', 'group_id': 29, 'seed': 2606, 'data_description': "V1 L2/3 on stimulus.Frame. normalize=True on all (except '')", 'stats_source': 'all', 'normalize': 1, 'normalize_per_image': 0, 'layer': 'L2/3', 'brain_area': 'V1'}
# 30-07-2019:06:16:51 INFO     data_schemas.py      987:	 Data will be (images,behavior,pupil_center,responses)
# 30-07-2019:06:16:51 INFO     data_schemas.py      990:	 Loading dataset group029-21067-9-17-0 --> /external/cache/static21067-9-17-preproc0.h5
# 30-07-2019:06:16:51 INFO     configs.py           208:	 Adding stats_source "all" to dataset
# 30-07-2019:06:16:51 INFO     configs.py           211:	 Using statistics source all
# 30-07-2019:06:16:51 INFO     configs.py            85:	 Excluding "" from normalization
# 30-07-2019:06:16:51 INFO     configs.py           177:	 Using stimulus.Frame as stimulus type for all datasets
# 30-07-2019:06:16:51 INFO     configs.py           180:	 Stimulus sources: "stimulus.Frame"
# 30-07-2019:06:16:51 INFO     configs.py           114:	 Using all trial from stimulus.Frame
# 30-07-2019:06:16:51 INFO     configs.py           188:	 Selecting trials from stimulus.Frame and tier=train for dataset group029-21067-9-17-0
# 30-07-2019:06:16:51 INFO     configs.py           190:	 Found 4475 active trials
# 30-07-2019:06:16:51 INFO     configs.py           150:	 Loader sampler is SubsetRandomSampler
# 30-07-2019:06:16:51 INFO     configs.py           152:	 Number of samples in the loader will be 4475
# 30-07-2019:06:16:51 INFO     configs.py           154:	 Number of batches in the loader will be 75
# 30-07-2019:06:16:51 INFO     configs.py           233:	 Subsampling to layer L2/3 and area(s) "V1"
# 30-07-2019:06:16:51 INFO     configs.py           399:	 Setting cuda=False
# 30-07-2019:06:16:51 INFO     cores.py              76:	 Ignoring input {'core_hash': '28bc2fa358337c5012278f899b5b6947'} when creating GaussianLaplaceCore
# 30-07-2019:06:16:51 INFO     readouts.py          140:	 Ignoring input {'ro_hash': 'e4cd67efe5a543b044cf8a74e440775e'} when creating SpatialTransformerPyramid2dReadout
# 30-07-2019:06:16:51 INFO     shifters.py           56:	 Ignoring input {'shift_hash': '05c69a4aeaeea5e48fa8fc5e70181d67'} when creating MLPShifter
# 30-07-2019:06:16:51 INFO     shifters.py           28:	 Ignoring input {} when creating MLP
# 30-07-2019:06:16:51 INFO     modulators.py         47:	 Ignoring input {'mod_hash': 'a757e992ae449e3057ff1d512a51bd1e'} when creating MLPModulator
# 30-07-2019:06:16:51 INFO     modulators.py         18:	 Ignoring input {} when creating MLP
# /usr/local/lib/python3.6/dist-packages/h5py/_hl/dataset.py:313: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   "Use dataset[()] instead.", H5pyDeprecationWarning)
# 30-07-2019:06:16:51 WARNING  models.py             82:	 Could not find paramater 'core.features.layer2.norm.num_batches_tracked' setting to initialization value
# 30-07-2019:06:16:51 WARNING  models.py             82:	 Could not find paramater 'core.features.layer1.norm.num_batches_tracked' setting to initialization value
# 30-07-2019:06:16:51 WARNING  models.py             82:	 Could not find paramater 'core.features.layer0.norm.num_batches_tracked' setting to initialization value
# 30-07-2019:06:16:51 INFO     configs.py           224:	 Ignoring input arguments: "net_hash", "core_hash", "ro_hash", "shift_hash", "mod_hash", "train_hash", "data_hash", "group_id", "seed", "train_type", "schedule", "max_epoch"when creating datasets
# 30-07-2019:06:16:51 INFO     configs.py           203:	 Loading None dataset with tier=train
# 30-07-2019:06:16:51 INFO     data_schemas.py      977:	 Fetching data for {'net_hash': '80d0d4bc112470b2ba04cd5eba048e39', 'core_hash': '28bc2fa358337c5012278f899b5b6947', 'ro_hash': 'e4cd67efe5a543b044cf8a74e440775e', 'shift_hash': '05c69a4aeaeea5e48fa8fc5e70181d67', 'mod_hash': 'a757e992ae449e3057ff1d512a51bd1e', 'train_hash': '2c25349fa0a81afbe907882e7b50a4da', 'data_hash': '7572eed73113c993e7d1b92f83e270b4', 'group_id': 29, 'seed': 99999, 'data_description': "V1 L2/3 on stimulus.Frame. normalize=True on all (except '')", 'stats_source': 'all', 'normalize': 1, 'normalize_per_image': 0, 'layer': 'L2/3', 'brain_area': 'V1'}
# 30-07-2019:06:16:51 INFO     data_schemas.py      987:	 Data will be (images,behavior,pupil_center,responses)
# 30-07-2019:06:16:51 INFO     data_schemas.py      990:	 Loading dataset group029-21067-9-17-0 --> /external/cache/static21067-9-17-preproc0.h5
# 30-07-2019:06:16:51 INFO     configs.py           208:	 Adding stats_source "all" to dataset
# 30-07-2019:06:16:51 INFO     configs.py           211:	 Using statistics source all
# 30-07-2019:06:16:51 INFO     configs.py            85:	 Excluding "" from normalization
# 30-07-2019:06:16:51 INFO     configs.py           177:	 Using stimulus.Frame as stimulus type for all datasets
# 30-07-2019:06:16:51 INFO     configs.py           180:	 Stimulus sources: "stimulus.Frame"
# 30-07-2019:06:16:51 INFO     configs.py           114:	 Using all trial from stimulus.Frame
# 30-07-2019:06:16:51 INFO     configs.py           188:	 Selecting trials from stimulus.Frame and tier=train for dataset group029-21067-9-17-0
# 30-07-2019:06:16:51 INFO     configs.py           190:	 Found 4475 active trials
# 30-07-2019:06:16:51 INFO     configs.py           150:	 Loader sampler is SubsetRandomSampler
# 30-07-2019:06:16:51 INFO     configs.py           152:	 Number of samples in the loader will be 4475
# 30-07-2019:06:16:51 INFO     configs.py           154:	 Number of batches in the loader will be 75
# 30-07-2019:06:16:51 INFO     configs.py           233:	 Subsampling to layer L2/3 and area(s) "V1"
# 30-07-2019:06:16:51 INFO     configs.py           399:	 Setting cuda=False
# 30-07-2019:06:16:51 INFO     cores.py              76:	 Ignoring input {'core_hash': '28bc2fa358337c5012278f899b5b6947'} when creating GaussianLaplaceCore
# 30-07-2019:06:16:51 INFO     readouts.py          140:	 Ignoring input {'ro_hash': 'e4cd67efe5a543b044cf8a74e440775e'} when creating SpatialTransformerPyramid2dReadout
# 30-07-2019:06:16:51 INFO     shifters.py           56:	 Ignoring input {'shift_hash': '05c69a4aeaeea5e48fa8fc5e70181d67'} when creating MLPShifter
# 30-07-2019:06:16:51 INFO     shifters.py           28:	 Ignoring input {} when creating MLP
# 30-07-2019:06:16:51 INFO     modulators.py         47:	 Ignoring input {'mod_hash': 'a757e992ae449e3057ff1d512a51bd1e'} when creating MLPModulator
# 30-07-2019:06:16:51 INFO     modulators.py         18:	 Ignoring input {} when creating MLP
# /usr/local/lib/python3.6/dist-packages/h5py/_hl/dataset.py:313: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   "Use dataset[()] instead.", H5pyDeprecationWarning)
# 30-07-2019:06:16:52 WARNING  models.py             82:	 Could not find paramater 'core.features.layer2.norm.num_batches_tracked' setting to initialization value
# 30-07-2019:06:16:52 WARNING  models.py             82:	 Could not find paramater 'core.features.layer1.norm.num_batches_tracked' setting to initialization value
# 30-07-2019:06:16:52 WARNING  models.py             82:	 Could not find paramater 'core.features.layer0.norm.num_batches_tracked' setting to initialization value

# %%
initial_image = torch.randn(1, 1, 36, 64, dtype=torch.float32, device=device)  # grayscale random image

# %% [markdown]
# ## Simplest optimization

# %% [markdown]
# ### SGD (no bells and whistles)

# %%
opt_x, fevals, reg_values = featurevis.gradient_ascent(model, initial_image, step_size=5, num_iterations=1000)
# Out:
# Iter 100: f(x) = 29.03, reg(x) = 0.00, std(x) = 2.64
# Iter 200: f(x) = 58.99, reg(x) = 0.00, std(x) = 5.06
# Iter 300: f(x) = 89.18, reg(x) = 0.00, std(x) = 7.57
# Iter 400: f(x) = 119.68, reg(x) = 0.00, std(x) = 10.10
# Iter 500: f(x) = 150.38, reg(x) = 0.00, std(x) = 12.65
# Iter 600: f(x) = 181.18, reg(x) = 0.00, std(x) = 15.21
# Iter 700: f(x) = 212.04, reg(x) = 0.00, std(x) = 17.77
# Iter 800: f(x) = 242.98, reg(x) = 0.00, std(x) = 20.34
# Iter 900: f(x) = 273.94, reg(x) = 0.00, std(x) = 22.91
# Iter 1000: f(x) = 304.90, reg(x) = 0.00, std(x) = 25.48
# Final f(x) = 305.20

# %%
fig, axes = plt.subplots(1, 2, figsize=(18, 5))
axes[0].plot(fevals)
axes[1].imshow(opt_x.squeeze().detach().cpu().numpy())

# %% [markdown]
# ### ADAM (no bells and whistles)

# %%
opt_x, fevals, reg_values = featurevis.gradient_ascent(model, initial_image, optim_name='Adam', step_size=0.1, num_iterations=200)
# Out:
# Iter 100: f(x) = 22.66, reg(x) = 0.00, std(x) = 6.94
# Iter 200: f(x) = 51.38, reg(x) = 0.00, std(x) = 13.15
# Final f(x) = 51.67

# %%
fig, axes = plt.subplots(1, 2, figsize=(18, 5))
axes[0].plot(fevals)
axes[1].imshow(opt_x.squeeze().detach().cpu().numpy())

# %% [markdown]
# ## DiCarlo (Bashivan et al., 2018)
# See Sec. *Synthesized "controller" images* in p.9.
# * Optimizer: SGD
# * Transform: Jittering
# * Regularization: Total variation
# * Gradient function: Normalize the gradient (grad / norm(grad)) and clip between -1 and 1.

# %%
dc_transform = ops.Jitter(max_jitter=(2, 4))
dc_regularization = ops.TotalVariation(weight=0.001)
dc_gradient = utils.Compose([ops.ChangeNorm(1), ops.ClipRange(-1, 1)])

# %%
opt_x, fevals, reg_values = featurevis.gradient_ascent(model, initial_image, step_size=1, num_iterations=700, 
                                                       transform=dc_transform, regularization=dc_regularization, 
                                                       gradient_f=dc_gradient)
# Out:
# Iter 100: f(x) = 5.15, reg(x) = 1.53, std(x) = 0.82
# Iter 200: f(x) = 2.05, reg(x) = 1.15, std(x) = 1.31
# Iter 300: f(x) = 16.66, reg(x) = 1.51, std(x) = 1.99
# Iter 400: f(x) = 17.71, reg(x) = 1.91, std(x) = 2.66
# Iter 500: f(x) = 35.10, reg(x) = 2.32, std(x) = 3.28
# Iter 600: f(x) = 3.09, reg(x) = 2.76, std(x) = 3.94
# Iter 700: f(x) = 7.71, reg(x) = 3.18, std(x) = 4.59
# Final f(x) = 3.63

# %%
fig, axes = plt.subplots(1, 3, figsize=(7*3, 4))
axes[0].plot(fevals)
axes[1].plot(reg_values)
axes[2].imshow(opt_x.squeeze().detach().cpu().numpy())

# %% [markdown]
# ## DeepTune (Abbasi-Asl, 2018)
# See Equation in p.8
# * Optimizer: SGD
# * Regularization: total variation and l6 norm

# %%
dt_regularization = utils.Combine([ops.TotalVariation(weight=0.001), ops.LpNorm(weight=1, p=6)])

# %%
opt_x, fevals, reg_values = featurevis.gradient_ascent(model, initial_image, step_size=1, num_iterations=500, 
                                                       regularization=dt_regularization)
# Out:
# Iter 100: f(x) = 3.76, reg(x) = 6.45, std(x) = 0.69
# Iter 200: f(x) = 3.65, reg(x) = 4.53, std(x) = 0.49
# Iter 300: f(x) = 3.34, reg(x) = 3.28, std(x) = 0.35
# Iter 400: f(x) = 3.17, reg(x) = 2.63, std(x) = 0.27
# Iter 500: f(x) = 3.12, reg(x) = 2.40, std(x) = 0.24
# Final f(x) = 3.12

# %%
fig, axes = plt.subplots(1, 3, figsize=(7*3, 4))
axes[0].plot(fevals)
axes[1].plot(reg_values)
axes[2].imshow(opt_x.squeeze().detach().cpu().numpy())

# %% [markdown]
# ## Ours (Walker et al., 2019)
# * Optimizer: SGD
# * Gradient: Fourier smoothing, divide by absolute mean of gradient, multiply by (step_gain/255) and multiply by a decaying learning rate
# * Post update: Clip range and blur image with a decaying sigma

# %%
walker_gradient = utils.Compose([ops.FourierSmoothing(0.04), # not exactly the same as fft_smooth(precond=0.1) but close
                                 ops.DeepDrawUpdateFactor(0.1),
                                 ops.MultiplyBy(3, decay_factor=(3 - 0.125) /(1-1000))])  # decays from 3 to 0.125 in 1000 iterations 
bias, scale = 111.28329467773438, 60.922306060791016
walker_postup = utils.Compose([ops.ClipRange(-bias / scale, (255 - bias) / scale), 
                               ops.GaussianBlur(1.5, decay_factor=(1.5 - 0.01) /(1-1000))]) # decays from 1.5 to 0.01 in 1000 iterations

# %%
opt_x, fevals, reg_values = featurevis.gradient_ascent(model, initial_image, step_size=1, num_iterations=1000, 
                                                       post_update=walker_postup, gradient_f=walker_gradient)
# Out:
# Iter 100: f(x) = 0.27, reg(x) = 0.00, std(x) = 0.03
# Iter 200: f(x) = 0.28, reg(x) = 0.00, std(x) = 0.04
# Iter 300: f(x) = 0.30, reg(x) = 0.00, std(x) = 0.04
# Iter 400: f(x) = 0.33, reg(x) = 0.00, std(x) = 0.05
# Iter 500: f(x) = 0.38, reg(x) = 0.00, std(x) = 0.05
# Iter 600: f(x) = 0.45, reg(x) = 0.00, std(x) = 0.06
# Iter 700: f(x) = 0.66, reg(x) = 0.00, std(x) = 0.07
# Iter 800: f(x) = 1.66, reg(x) = 0.00, std(x) = 0.11
# Iter 900: f(x) = 2.85, reg(x) = 0.00, std(x) = 0.18
# Iter 1000: f(x) = 3.33, reg(x) = 0.00, std(x) = 0.22
# Final f(x) = 3.34

# %%
fig, axes = plt.subplots(1, 2, figsize=(18, 5))
axes[0].plot(fevals)
axes[1].imshow(opt_x.squeeze().detach().cpu().numpy())

# %%
mei = (multi_mei.MEI & key).fetch1('mei')
plt.figure(figsize=(8, 5))
plt.imshow(mei)
plt.title('MEI from deepdraw')
# Out:
# Text(0.5, 1.0, 'MEI from deepdraw')

# %% [markdown]
# ## Alternative MEI generation
# TODO: Finding the simplest way to generate robust MEIs
# * Optimizer: SGD
# * Post update: Keep std to 1.

# %%
alt_postup = ops.ChangeStd(1)

# %%
opt_x, fevals, reg_values = featurevis.gradient_ascent(model, initial_image, step_size=1, num_iterations=1000, 
                                                        post_update=alt_postup)
# Out:
# Iter 100: f(x) = 6.11, reg(x) = 0.00, std(x) = 1.00
# Iter 200: f(x) = 9.51, reg(x) = 0.00, std(x) = 1.00
# Iter 300: f(x) = 11.33, reg(x) = 0.00, std(x) = 1.00
# Iter 400: f(x) = 12.16, reg(x) = 0.00, std(x) = 1.00
# Iter 500: f(x) = 12.49, reg(x) = 0.00, std(x) = 1.00
# Iter 600: f(x) = 12.63, reg(x) = 0.00, std(x) = 1.00
# Iter 700: f(x) = 12.68, reg(x) = 0.00, std(x) = 1.00
# Iter 800: f(x) = 12.71, reg(x) = 0.00, std(x) = 1.00
# Iter 900: f(x) = 12.74, reg(x) = 0.00, std(x) = 1.00
# Iter 1000: f(x) = 12.75, reg(x) = 0.00, std(x) = 1.00
# Final f(x) = 12.75

# %%
fig, axes = plt.subplots(1, 2, figsize=(18, 5))
axes[0].plot(fevals)
axes[1].imshow(opt_x.squeeze().detach().cpu().numpy())

# %% [markdown]
# ## LEI (least exciting image)

# %%
lei_model = utils.Compose([model, ops.MultiplyBy(-1)]) # negative model
lei_postup = ops.ChangeStd(1)

# %%
opt_x, fevals, reg_values = featurevis.gradient_ascent(lei_model, initial_image, step_size=1, num_iterations=1000, 
                                                        post_update=lei_postup)
# Out:
# Iter 100: f(x) = -0.16, reg(x) = 0.00, std(x) = 1.00
# Iter 200: f(x) = -0.12, reg(x) = 0.00, std(x) = 1.00
# Iter 300: f(x) = -0.10, reg(x) = 0.00, std(x) = 1.00
# Iter 400: f(x) = -0.09, reg(x) = 0.00, std(x) = 1.00
# Iter 500: f(x) = -0.08, reg(x) = 0.00, std(x) = 1.00
# Iter 600: f(x) = -0.08, reg(x) = 0.00, std(x) = 1.00
# Iter 700: f(x) = -0.07, reg(x) = 0.00, std(x) = 1.00
# Iter 800: f(x) = -0.07, reg(x) = 0.00, std(x) = 1.00
# Iter 900: f(x) = -0.07, reg(x) = 0.00, std(x) = 1.00
# Iter 1000: f(x) = -0.06, reg(x) = 0.00, std(x) = 1.00
# Final f(x) = -0.06

# %%
fig, axes = plt.subplots(1, 2, figsize=(18, 5))
axes[0].plot(fevals)
axes[1].imshow(opt_x.squeeze().detach().cpu().numpy())

# %% [markdown]
# ## Checking evolution of MEI
# Just to show `save_iters`. Something similar could be used to run early stopping (by testing intermediate MEIs in a validation model).

# %%
opt_x, fevals, reg_values = featurevis.gradient_ascent(model, initial_image, step_size=10, num_iterations=100, save_iters=20)
# Out:
# Iter 100: f(x) = 58.37, reg(x) = 0.00, std(x) = 5.04
# Final f(x) = 58.97

# %%
fig, axes = plt.subplots(1, 6, figsize=(20, 3))
axes[0].set_title('Iter {} f(x) = {:.2f}'.format(0, fevals[0]))
axes[0].imshow(initial_image.squeeze().detach().cpu().numpy())
for ax, i, one_x in zip(axes[1:], range(20, 101, 20), opt_x):
    ax.imshow(one_x.squeeze().detach().cpu().numpy())
    ax.set_title('Iter {}: f(x) = {:.2f}'.format(i, fevals[i]))

# %% [markdown]
# ## Create an MEI in the center of the screen
# Just to show `x_shift` and `y_shift`:
# * Sending `eye_pos=None` (default) gets rid of the overall pupil shift.
# * Sending `x_shift=0` and `y_shift=0` gets rid of the per-cell learnt shift.

# %%
center_model = models.Ensemble(my_models, key['readout_key'], neuron_idx=key['neuron_id'], 
                               x_shift=0, y_shift=0, device=device)

# %%
initial_image_square = torch.randn(1, 1, 32+14, 32+14, dtype=torch.float32, device=device)

# %%
opt_x, fevals, reg_values = featurevis.gradient_ascent(center_model, initial_image_square, step_size=100, num_iterations=100)
# Out:
# Iter 100: f(x) = 393.37, reg(x) = 0.00, std(x) = 43.19
# Final f(x) = 397.32

# %%
fig, axes = plt.subplots(1, 2, figsize=(18, 5))
axes[0].plot(fevals)
axes[1].imshow(opt_x.squeeze().detach().cpu().numpy())
axes[1].grid()
axes[1].set_yticks([opt_x.squeeze().shape[0] / 2 -0.5])
axes[1].set_xticks([opt_x.squeeze().shape[1] / 2 -0.5])

# %% [markdown]
# ## Diverse MEIs

# %%
initial_batch = torch.randn(5, 1, 36, 64, dtype=torch.float32, device=device) # 5 grayscale random images
mask = None

# %%
# mask that contains the relevant part of the image (if available)
from staticnet_analyses import largefov
mask = torch.as_tensor((largefov.MEIMask & key).fetch1('mask'), dtype=torch.float32, device=device)

# %% [markdown]
# ### Computing similarity in pixel space

# %%
div_regularization = ops.Similarity(10, mask=mask, metric='correlation')
div_postup = ops.ChangeStd(1)

# %%
opt_x, fevals, reg_values = featurevis.gradient_ascent(model, initial_batch, step_size=10, num_iterations=500, 
                                                       regularization=div_regularization, post_update=div_postup)
# Out:
# Iter 100: f(x) = 5.60, reg(x) = -1.18, std(x) = 1.00
# Iter 200: f(x) = 7.69, reg(x) = -1.57, std(x) = 1.00
# Iter 300: f(x) = 8.48, reg(x) = -1.45, std(x) = 1.00
# Iter 400: f(x) = 8.87, reg(x) = -1.39, std(x) = 1.00
# Iter 500: f(x) = 8.90, reg(x) = -1.63, std(x) = 1.00
# Final f(x) = 8.90

# %%
fig, axes = plt.subplots(1, 2, figsize=(18, 5))
axes[0].plot(fevals)
axes[1].plot(reg_values)

# %%
fig, axes = plt.subplots(1, len(opt_x), figsize=(20, 3))
for ax, one_x in zip(axes, opt_x):
    ax.imshow(one_x.squeeze().detach().cpu().numpy())

# %% [markdown]
# ### Computing similarity in (VGG-19) feature space

# %%
from torch.nn import functional as F
mini_mask = F.avg_pool2d(mask.unsqueeze(0).unsqueeze(0), kernel_size=4).squeeze() # the VGG features get downsampled twice

# %%
div_regularization = utils.Compose([ops.GrayscaleToRGB(), models.VGG19Core(layer=15), 
                                    ops.Similarity(0.02, mask=mini_mask, metric='euclidean')])
div_postup = ops.ChangeStd(1)

# %%
opt_x, fevals, reg_values = featurevis.gradient_ascent(model, initial_batch, step_size=10, num_iterations=500, 
                                                       regularization=div_regularization, post_update=div_postup)
# Out:
# Iter 100: f(x) = 9.34, reg(x) = -1.06, std(x) = 1.00
# Iter 200: f(x) = 11.60, reg(x) = -1.43, std(x) = 1.00
# Iter 300: f(x) = 11.98, reg(x) = -1.60, std(x) = 1.00
# Iter 400: f(x) = 12.05, reg(x) = -1.72, std(x) = 1.00
# Iter 500: f(x) = 12.09, reg(x) = -1.77, std(x) = 1.00
# Final f(x) = 12.08

# %%
fig, axes = plt.subplots(1, 2, figsize=(18, 5))
axes[0].plot(fevals)
axes[1].plot(reg_values)

# %%
fig, axes = plt.subplots(1, len(opt_x), figsize=(20, 3))
for ax, one_x in zip(axes, opt_x):
    ax.imshow(one_x.squeeze().detach().cpu().numpy())

# %% [markdown]
# ## Most exciting Gabor
# * Optimizer: Adam (worked better than SGD in this example)
# * Input: orientation, phase, wavelength, sigma, dx, dy
# * Transform: change parameters range to a nice range and then generate the Gabor with them.

# %%
initial_x = torch.randn(1, 6, dtype=torch.float32, device=device) # orientation, phase, wavelength, sigma, dx, dy

# %%
import math
min_x = torch.tensor([0, 0, 0.12, 0.04, -0.5, -0.5], dtype=torch.float32, device=device)
max_x = torch.tensor([math.pi, 2 * math.pi, 1.5, 1, 0.5, 0.5], dtype=torch.float32, device=device)
gabor_transform = utils.Compose([ops.ChangeRange(min_x, max_x), ops.GaborGenerator(36, 62)])

# %%
opt_x, fevals, reg_values = featurevis.gradient_ascent(model, initial_x, optim_name='Adam', step_size=1, 
                                                       num_iterations=200, transform=gabor_transform)
# Out:
# Iter 100: f(x) = 0.48, reg(x) = 0.00, std(x) = 5.59
# Iter 200: f(x) = 0.48, reg(x) = 0.00, std(x) = 5.63
# Final f(x) = 0.48

# %%
fig, axes = plt.subplots(1, 2, figsize=(18, 5))
axes[0].plot(fevals)
axes[1].imshow(gabor_transform(opt_x).squeeze().detach().cpu().numpy())

# %% [markdown]
# ## Texture
# ### Random crops
# * Optimizer: SGD
# * Transform: Take a random crop from the big image

# %%
initial_image2 = torch.randn(1, 1, 36*2, 62*2, dtype=torch.float32, device=device)
text_transform = ops.RandomCrop(36, 62)

# %%
opt_x, fevals, reg_values = featurevis.gradient_ascent(model, initial_image2, step_size=5, num_iterations=4000, transform=text_transform)
# Out:
# Iter 100: f(x) = 0.58, reg(x) = 0.00, std(x) = 1.02
# Iter 200: f(x) = 0.89, reg(x) = 0.00, std(x) = 1.04
# Iter 300: f(x) = 0.56, reg(x) = 0.00, std(x) = 1.06
# Iter 400: f(x) = 0.60, reg(x) = 0.00, std(x) = 1.08
# Iter 500: f(x) = 0.64, reg(x) = 0.00, std(x) = 1.11
# Iter 600: f(x) = 1.04, reg(x) = 0.00, std(x) = 1.14
# Iter 700: f(x) = 1.87, reg(x) = 0.00, std(x) = 1.18
# Iter 800: f(x) = 0.81, reg(x) = 0.00, std(x) = 1.21
# Iter 900: f(x) = 3.28, reg(x) = 0.00, std(x) = 1.25
# Iter 1000: f(x) = 0.73, reg(x) = 0.00, std(x) = 1.29
# Iter 1100: f(x) = 2.81, reg(x) = 0.00, std(x) = 1.33
# Iter 1200: f(x) = 0.73, reg(x) = 0.00, std(x) = 1.37
# Iter 1300: f(x) = 1.58, reg(x) = 0.00, std(x) = 1.41
# Iter 1400: f(x) = 0.61, reg(x) = 0.00, std(x) = 1.46
# Iter 1500: f(x) = 3.81, reg(x) = 0.00, std(x) = 1.51
# Iter 1600: f(x) = 2.47, reg(x) = 0.00, std(x) = 1.56
# Iter 1700: f(x) = 5.80, reg(x) = 0.00, std(x) = 1.62
# Iter 1800: f(x) = 1.45, reg(x) = 0.00, std(x) = 1.67
# Iter 1900: f(x) = 5.90, reg(x) = 0.00, std(x) = 1.72
# Iter 2000: f(x) = 7.61, reg(x) = 0.00, std(x) = 1.78
# Iter 2100: f(x) = 4.00, reg(x) = 0.00, std(x) = 1.84
# Iter 2200: f(x) = 2.66, reg(x) = 0.00, std(x) = 1.89
# Iter 2300: f(x) = 0.67, reg(x) = 0.00, std(x) = 1.94
# Iter 2400: f(x) = 6.08, reg(x) = 0.00, std(x) = 2.00
# Iter 2500: f(x) = 4.23, reg(x) = 0.00, std(x) = 2.06
# Iter 2600: f(x) = 1.37, reg(x) = 0.00, std(x) = 2.12
# Iter 2700: f(x) = 3.79, reg(x) = 0.00, std(x) = 2.19
# Iter 2800: f(x) = 1.08, reg(x) = 0.00, std(x) = 2.25
# Iter 2900: f(x) = 2.36, reg(x) = 0.00, std(x) = 2.30
# Iter 3000: f(x) = 6.90, reg(x) = 0.00, std(x) = 2.36
# Iter 3100: f(x) = 2.19, reg(x) = 0.00, std(x) = 2.42
# Iter 3200: f(x) = 0.77, reg(x) = 0.00, std(x) = 2.48
# Iter 3300: f(x) = 5.42, reg(x) = 0.00, std(x) = 2.55
# Iter 3400: f(x) = 8.46, reg(x) = 0.00, std(x) = 2.60
# Iter 3500: f(x) = 3.82, reg(x) = 0.00, std(x) = 2.67
# Iter 3600: f(x) = 0.45, reg(x) = 0.00, std(x) = 2.72
# Iter 3700: f(x) = 3.80, reg(x) = 0.00, std(x) = 2.78
# Iter 3800: f(x) = 2.67, reg(x) = 0.00, std(x) = 2.85
# Iter 3900: f(x) = 7.62, reg(x) = 0.00, std(x) = 2.91
# Iter 4000: f(x) = 8.87, reg(x) = 0.00, std(x) = 2.98
# Final f(x) = 9.54

# %%
fig, axes = plt.subplots(1, 2, figsize=(18, 5))
axes[0].plot(fevals)
axes[1].imshow(opt_x.squeeze().detach().cpu().numpy())

# %% [markdown]
# ### Batched random crops (a la Santiago)
# * Optimizer: SGD
# * Transform: Create a batch with overlapping tiles of the big image, optimize the mean activity overall
#
# Doesn't look as nice. Also, I ran out of memory for bigger FOV.

# %%
initial_image2 = torch.randn(1, 1, 36 + 18, 62 + 31, dtype=torch.float32, device=device)
text_transform = ops.BatchedCrops(36, 62, step_size=5, sigma=(8, 12))

# %%
opt_x, fevals, reg_values = featurevis.gradient_ascent(model, initial_image2, step_size=10, num_iterations=400, transform=text_transform)
# Out:
# Iter 100: f(x) = 1.75, reg(x) = 0.00, std(x) = 1.14
# Iter 200: f(x) = 2.80, reg(x) = 0.00, std(x) = 1.39
# Iter 300: f(x) = 3.78, reg(x) = 0.00, std(x) = 1.71
# Iter 400: f(x) = 4.79, reg(x) = 0.00, std(x) = 2.07
# Final f(x) = 4.80

# %%
fig, axes = plt.subplots(1, 2, figsize=(18, 5))
axes[0].plot(fevals)
axes[1].imshow(opt_x.squeeze().detach().cpu().numpy())

# %% [markdown]
# ## In VGG19

# %% [markdown]
# Let's  download a pretrained model

# %%
#model = models.VGG19(layer=14, channel=13, device=device) # conv 3_1, feature map 13
model = models.VGG19(layer=40, channel=150, device=device) # conv 5_1, feature map 150

# %%
initial_image = torch.randn(1, 3, 128, 128, dtype=torch.float32, device=device) # 128 x 128 RGB image

# %% [markdown]
# ### MEI

# %%
opt_x, fevals, reg_values = featurevis.gradient_ascent(model, initial_image, optim_name='Adam', step_size=0.1, num_iterations=1000, 
                                                       transform=ops.Jitter(3), # jitter to avoid adversarial effects
                                                       gradient_f=ops.GaussianBlur(1), # bit of blurring on gradient to avoid high freq effects
                                                       post_update=ops.ChangeStd(1)) # keep the image in a reasonable range
# Out:
# Iter 100: f(x) = 2.11, reg(x) = 0.00, std(x) = 1.00
# Iter 200: f(x) = 2.87, reg(x) = 0.00, std(x) = 1.00
# Iter 300: f(x) = 2.86, reg(x) = 0.00, std(x) = 1.00
# Iter 400: f(x) = 3.28, reg(x) = 0.00, std(x) = 1.00
# Iter 500: f(x) = 3.45, reg(x) = 0.00, std(x) = 1.00
# Iter 600: f(x) = 3.15, reg(x) = 0.00, std(x) = 1.00
# Iter 700: f(x) = 3.16, reg(x) = 0.00, std(x) = 1.00
# Iter 800: f(x) = 3.63, reg(x) = 0.00, std(x) = 1.00
# Iter 900: f(x) = 3.54, reg(x) = 0.00, std(x) = 1.00
# Iter 1000: f(x) = 3.59, reg(x) = 0.00, std(x) = 1.00
# Final f(x) = 3.34

# %%
fig, axes = plt.subplots(1, 3, figsize=(21, 7))
axes[0].plot(fevals)
im = opt_x.squeeze().transpose(0, -1).detach().cpu().numpy()
im = (im - im.min(axis=(0, 1))) / (im.max(axis=(0, 1)) - im.min(axis=(0, 1)))
axes[1].imshow(im)
axes[2].imshow(opt_x.squeeze().transpose(0, -1).detach().cpu().numpy() / 2 + 0.5)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ### LEI

# %%
lei_model = utils.Compose([model, ops.MultiplyBy(-1)]) # find least activating features 
opt_x, fevals, reg_values = featurevis.gradient_ascent(lei_model, initial_image, optim_name='Adam', step_size=0.1, num_iterations=1000, 
                                                       transform=ops.Jitter(3), # jitter to avoid adversarial effects
                                                       gradient_f=ops.GaussianBlur(1), # bit of blurring on gradient to avoid high freq effects
                                                       post_update=ops.ChangeStd(1)) # keep the image in a reasonable range
# Out:
# Iter 100: f(x) = 2.80, reg(x) = 0.00, std(x) = 1.00
# Iter 200: f(x) = 3.20, reg(x) = 0.00, std(x) = 1.00
# Iter 300: f(x) = 3.56, reg(x) = 0.00, std(x) = 1.00
# Iter 400: f(x) = 3.71, reg(x) = 0.00, std(x) = 1.00
# Iter 500: f(x) = 3.68, reg(x) = 0.00, std(x) = 1.00
# Iter 600: f(x) = 4.01, reg(x) = 0.00, std(x) = 1.00
# Iter 700: f(x) = 4.03, reg(x) = 0.00, std(x) = 1.00
# Iter 800: f(x) = 4.09, reg(x) = 0.00, std(x) = 1.00
# Iter 900: f(x) = 3.87, reg(x) = 0.00, std(x) = 1.00
# Iter 1000: f(x) = 4.03, reg(x) = 0.00, std(x) = 1.00
# Final f(x) = 3.90

# %%
fig, axes = plt.subplots(1, 3, figsize=(21, 7))
axes[0].plot(fevals)
im = opt_x.squeeze().transpose(0, -1).detach().cpu().numpy()
im = (im - im.min(axis=(0, 1))) / (im.max(axis=(0, 1)) - im.min(axis=(0, 1)))
axes[1].imshow(im)
axes[2].imshow(opt_x.squeeze().transpose(0, -1).detach().cpu().numpy() / 3 + 0.5)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
